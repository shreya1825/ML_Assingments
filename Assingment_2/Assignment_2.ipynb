# %%
#1 Question
import numpy as np
a= np.random.random((10, 1))
print(a)
print(np.mean(a))
# Out:
# [[0.4517359 ]
#  [0.74958259]
#  [0.43989153]
#  [0.04497618]
#  [0.48206598]
#  [0.59252891]
#  [0.62712933]
#  [0.34312288]
#  [0.36467797]
#  [0.59932498]]
# 0.46950362442424637

# %%
# 2 Question
a=np.random.random((20,1))
print(a)
print("Variacne is:")
print(np.var(a))
print("Standard deviation:")
print(np.std(a))
# Out:
# [[0.30596428]
#  [0.62885692]
#  [0.65982801]
#  [0.38511552]
#  [0.89720573]
#  [0.37577185]
#  [0.80020062]
#  [0.38131294]
#  [0.46423301]
#  [0.85307439]
#  [0.68979128]
#  [0.06379647]
#  [0.34990682]
#  [0.68008596]
#  [0.76274984]
#  [0.52576985]
#  [0.48066406]
#  [0.45461417]
#  [0.97964804]
#  [0.79351996]]
# Variacne is:
# 0.05242934722300756
# Standard deviation:
# 0.22897455584192658

# %%
#Question 3
b= np.random.random((10, 20))
c=np.random.random((20,25))
r=b.dot(c)
print(r.shape)
print("Matrix multiplication=",r)
print("Addition=",np.sum(r))
# Out:
# (10, 25)
# Matrix multiplication= [[4.5708561  4.1543979  5.70330805 3.99481406 3.3813424  4.91420696
#   4.56823016 5.06270168 5.34671642 4.1580397  4.0442751  4.38628364
#   5.52888335 4.65325483 4.45349996 5.21944342 4.28510732 4.48258784
#   3.92087298 4.88964431 4.80536523 4.51573211 4.05355561 4.17478781
#   4.71547512]
#  [5.24035066 4.67863814 5.40619624 4.20838538 3.76606607 4.32611132
#   4.37483563 4.76909797 5.88743148 4.27333498 3.9146521  4.24253617
#   5.98541067 4.12444702 4.79809857 4.4317755  4.26225662 4.53550982
#   4.49010838 5.17534683 5.26917096 4.60822067 4.58726561 4.60363361
#   5.01989508]
#  [4.88154864 4.49769634 4.91072331 4.16628142 3.45764056 4.47636249
#   3.85965614 4.79886598 5.31655587 3.67614972 4.19593956 3.9676176
#   5.32993064 4.1445381  4.74382172 4.75998016 4.2847639  4.33860036
#   4.28170634 5.15823936 5.16759892 4.33632408 4.08092535 4.92882129
#   4.57926798]
#  [5.14263007 4.24466555 5.38004514 4.04826717 3.49289576 5.11200317
# ...

# %%
#Question 4
import math
import numpy as np
x=np.random.rand(10,1)
q=lambda x:1/1+np.exp(-x)
y=np.array([q(xi) for xi in x])
print(y)
# Out:
# [[1.66431481]
#  [1.99214343]
#  [1.81027169]
#  [1.72981654]
#  [1.73210312]
#  [1.384109  ]
#  [1.55304158]
#  [1.74057851]
#  [1.80769749]
#  [1.65108833]]
