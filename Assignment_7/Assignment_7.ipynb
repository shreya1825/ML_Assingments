# %% [markdown]
#  <h1><u>WineQuality-White Reviews:EDA</u></h1>
#
# <br><br><br>
# <h2>
# Dataset statistics:-<br><br>
# Number of rows :4898<br><br>
# Number of cols :12<br><br>
# Samples with pH>3:4387<br><br>
# </h2>

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Shreya katoch\Desktop\regression\winequality-white.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_ph=(df['pH']>3)
df_ph.value_counts()
# Out:
# True     4387
# False     511
# Name: pH, dtype: int64

# %%
#count of missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df[['pH','citric acid']].hist(figsize=(11,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FC6F0A60B8>,
# ...
#       dtype=object)

# %%
sns.boxplot(df['total sulfur dioxide'])

# %%
sns.kdeplot(df['density'])

# %% [markdown]
#  <h2>Bivariate Analysis - Plot the bivariate graphs and find the relationship between the variables.</h2>

# %%
df.plot(kind='scatter', x = 'chlorides',y='free sulfur dioxide')

# %%
sns.jointplot(x='quality', y='alcohol', data=df)
# Out:
# C:\Users\Shreya katoch\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Shreya katoch\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x=df['fixed acidity'], y=df['volatile acidity'], data=df, kind='kde')

# %%
sns.boxplot(data=df['pH'])

# %%
sns.jointplot(x = df['pH'], y =df['density'], kind='hex',  color='k')
# Out:
# C:\Users\Shreya katoch\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Shreya katoch\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <h3>
# Note:-
# Most values of density lies between 0.99-1.00 .<br>
#
# Most values of pH lies between 3.0-3.4 .<br>
#
# The histogram plot of pH shows that it almost follows normal distribution.<br>
#
# The mid value region of both is the most dense.<br>
#
# </h3>

# %%
sns.barplot(x='quality', y='chlorides', data=df)

# %%
sns.swarmplot(x ='quality' , y='sulphates', data=df)

# %% [markdown]
# <h1>
# Multivariate Analysis</h1>

# %%
temp_df=df[['pH','quality','volatile acidity','chlorides']]
sns.pairplot(temp_df)

# %%
temp_df=df[['alcohol','citric acid','sulphates','pH']]
sns.pairplot(temp_df)
